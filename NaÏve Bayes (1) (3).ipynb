# %%
pwd
# Out:
# 'C:\\Users\\djsce.student'

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df=pd.read_csv('breastcancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
m_count=b_count=0
for rows in range(0,len(df)):
    if df['diagnosis'][rows] is 'M':
        df['diagnosis'][rows]=0
        m_count=m_count+1
    else:
        df['diagnosis'][rows]=1
        b_count=b_count+1
# Out:
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\djsce.student\AppData\Local\Temp\ipykernel_10712\104185962.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if df['diagnosis'][rows] is 'M':
# C:\Users\djsce.student\AppData\Local\Temp\ipykernel_10712\104185962.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diagnosis'][rows]=0
# C:\Users\djsce.student\AppData\Local\Temp\ipykernel_10712\104185962.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diagnosis'][rows]=1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(['id','diagnosis','Unnamed: 32'],axis=1),df['diagnosis'],test_size=0.2)

# %%
df.drop('Unnamed: 32',axis=1,inplace=True)

# %%
class NaiveBayes:
    def __init__(self,df):
        self.df=df
        self.maindict=maindict={}
    def train(self,X_train,y_train):
        self.X_train=X_train
        X_train=self.X_train
        X_train.reset_index(inplace=True)
        
        X_train['preds']=y_train
        maindict=self.maindict
        for uniq in X_train['preds'].unique():
            dicts={}
            df1=X_train[X_train['preds']==uniq]
            print(len(df1))
            df1.drop('index',inplace=True,axis=1)
            df1.reset_index(inplace=True)
            for columns in df1.columns:
                mean=(df1[columns].sum()/len(df1))
                errorsum=0
                for rows in range(0,len(df1)):
                    errorsum=errorsum+(df1[columns][rows]-mean)**2
                stdev=((errorsum/(len(df1)-1))**0.5)
                
                dicts[columns]=[len(df1)/len(X_train),mean,stdev]
            maindict[uniq]=dicts
    def test(self,X_test):
        prob={}
        for rows in range(0,len(X_test)):
            for columns in X_test.columns:
                pass

# %%
nb=NaiveBayes(df)

# %%
nb.train(X_train,y_train)
# Out:
# 147
# 0
# C:\Users\djsce.student\AppData\Local\Temp\ipykernel_10712\3614494815.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('index',inplace=True,axis=1)
# C:\Users\djsce.student\AppData\Local\Temp\ipykernel_10712\3614494815.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('index',inplace=True,axis=1)
# C:\Users\djsce.student\AppData\Local\Temp\ipykernel_10712\3614494815.py:19: RuntimeWarning: invalid value encountered in longlong_scalars
#   mean=(df1[columns].sum()/len(df1))
# ...

# %%
df['diagnosis'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
df['diagnosis'].unique()
X_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 244       19.400         23.50          129.10     1155.0          0.10270
# 237       20.480         21.46          132.50     1306.0          0.08355
# 489       16.690         20.20          107.10      857.6          0.07497
# 263       15.610         19.38          100.00      758.6          0.07840
# 119       17.950         20.01          114.20      982.0          0.08402
# ..           ...           ...             ...        ...              ...
# 24        16.650         21.38          110.00      904.6          0.11210
# 514       15.050         19.07           97.26      701.9          0.09215
# 61         8.598         20.98           54.66      221.8          0.12430
# 522       11.260         19.83           71.30      388.1          0.08511
# 77        18.050         16.15          120.20     1006.0          0.10650
#
# ...

# %%
y_train
# Out:
# 330    0
# 236    0
# 207    0
# 492    0
# 274    0
#       ..
# 436    1
# 39     0
# 495    1
# 68     1
# 429    1
# Name: diagnosis, Length: 455, dtype: object

# %%
for uniq in df['diagnosis'].unique():
    df1=df[df['diagnosis']==uniq]
    df1.head()

# %%
df1
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19    8510426         1       13.540         14.36           87.46      566.3
# 20    8510653         1       13.080         15.71           85.63      520.0
# 21    8510824         1        9.504         12.44           60.34      273.9
# 37     854941         1       13.030         18.42           82.61      523.8
# 46   85713702         1        8.196         16.84           51.71      201.9
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         1       14.590         22.68           96.39      657.1
# 559    925291         1       11.510         23.93           74.52      403.5
# 560    925292         1       14.050         27.15           91.38      600.4
# 561    925311         1       11.200         29.37           70.67      386.0
# 568     92751         1        7.760         24.54           47.92      181.0
#
# ...

# %%
len(df)
# Out:
# 569
